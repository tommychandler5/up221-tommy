# %% [markdown]
# ## Week 4 Individual Assignment
# # Mapping Land Use and zoning in San Francisco (2015)
#
# For this week's hoemwork assignment, I will be mapping certain land uses in San Francisco as a categorical variable impacting public health and asmtha rates in the city. The data I am using is a GeoJSON file of the 2015 Zoning Map from the SF Data Portal. I decided to use the map from 2015 because our group is using data on asmtha rates and poverty levels that is based on the 2010 Census. The California Department for Housing and Community Development requires jurisdictions update their Land Use and Housing Elements on specific planning cycles. On July 18, 2013, the ABAG (Association for Bay Area Governments) issued the final RHNA allocations to jurisdictions with the deadline of having their updated housing elements approved by HCD by January 31, 2015. SF's 2014 Housing Element was approved on May 29, 2015. As such, I've used the 2015 zoning map to compare against asthma and health insurance data from the 2010 census.
#
# My group plans to use the outputs of this assignment to
# Make land use map interactive to isolate different land uses - esp industrial
# trying to over lay the different zones onto census tracts for comparison to asthma rates and historic redline maps.

# %%
#importing libraries
import pandas as pd
import geopandas as gpd
import plotly.express as px

# %%
#loading the 2015 Zoning Maps' GeoJSON data file as geopandas
df = gpd.read_file('data/SFZoningDistricts_Jan2015.geojson')

# %% [markdown]
# # Inspecting and Cleaning Up the Data

# %%
#inspecting the shape of the file
df.shape
# Out:
# (9978, 7)

# %%
df.head()
# Out:
#   zoning_sim                               districtna     shape_area  \
# 0       NC-3  NEIGHBORHOOD COMMERCIAL, MODERATE SCALE  13901.1426915
# 1       NC-3  NEIGHBORHOOD COMMERCIAL, MODERATE SCALE  11413.2653614
# 2       NC-3  NEIGHBORHOOD COMMERCIAL, MODERATE SCALE  14482.4919657
# 3       NC-3  NEIGHBORHOOD COMMERCIAL, MODERATE SCALE  54869.3000022
# 4       NC-3  NEIGHBORHOOD COMMERCIAL, MODERATE SCALE  12643.7618017
#
#                                                  url multigeom      shape_len  \
# 0  http://www.amlegal.com/nxt/gateway.dll/Califor...     false  552.715581654
# 1  http://www.amlegal.com/nxt/gateway.dll/Califor...     false  602.155213139
# 2  http://www.amlegal.com/nxt/gateway.dll/Califor...     false   607.84767868
# 3  http://www.amlegal.com/nxt/gateway.dll/Califor...     false  1524.97422258
# 4  http://www.amlegal.com/nxt/gateway.dll/Califor...     false  478.416741548
#
#                                             geometry
# 0  POLYGON ((-122.39202 37.73010, -122.39207 37.7...
# 1  POLYGON ((-122.39165 37.73087, -122.39172 37.7...
# 2  POLYGON ((-122.39134 37.73169, -122.39144 37.7...
# 3  POLYGON ((-122.39187 37.73195, -122.39190 37.7...
# 4  POLYGON ((-122.39103 37.73262, -122.39113 37.7...

# %%
# Looking at the data types
df.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 9978 entries, 0 to 9977
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   zoning_sim  9978 non-null   object
#  1   districtna  9978 non-null   object
#  2   shape_area  9978 non-null   object
#  3   url         9909 non-null   object
#  4   multigeom   9978 non-null   object
#  5   shape_len   9978 non-null   object
#  6   geometry    9978 non-null   geometry
# dtypes: geometry(1), object(6)
# memory usage: 545.8+ KB

# %%
# Defining the columns to keep (zoning district name, zoning use abbreviation, area, and geometry).
columns_to_keep = ['districtna',
                   'zoning_sim',
                   'shape_area',
                   'geometry']

# %%
# Adding these columns to a new dataframe
df2 = df[columns_to_keep].copy()
df2
# Out:
#                                          districtna zoning_sim     shape_area  \
# 0           NEIGHBORHOOD COMMERCIAL, MODERATE SCALE       NC-3  13901.1426915
# 1           NEIGHBORHOOD COMMERCIAL, MODERATE SCALE       NC-3  11413.2653614
# 2           NEIGHBORHOOD COMMERCIAL, MODERATE SCALE       NC-3  14482.4919657
# 3           NEIGHBORHOOD COMMERCIAL, MODERATE SCALE       NC-3  54869.3000022
# 4           NEIGHBORHOOD COMMERCIAL, MODERATE SCALE       NC-3  12643.7618017
# ...                                             ...        ...            ...
# 9973                    EXCELSIOR OUTER MISSION NCD        NCD  15828.0104436
# 9974                    EXCELSIOR OUTER MISSION NCD        NCD  24179.2035499
# 9975                    EXCELSIOR OUTER MISSION NCD        NCD  31868.2001932
# 9976                    EXCELSIOR OUTER MISSION NCD        NCD  23104.3156526
# 9977  JUDAH STREET NEIGHBORHOOD COMMERCIAL DISTRICT        NCD  24098.9309351
#
#                                                geometry
# 0     POLYGON ((-122.39202 37.73010, -122.39207 37.7...
# 1     POLYGON ((-122.39165 37.73087, -122.39172 37.7...
# 2     POLYGON ((-122.39134 37.73169, -122.39144 37.7...
# 3     POLYGON ((-122.39187 37.73195, -122.39190 37.7...
# 4     POLYGON ((-122.39103 37.73262, -122.39113 37.7...
# ...                                                 ...
# 9973  POLYGON ((-122.44363 37.71318, -122.44378 37.7...
# 9974  POLYGON ((-122.44272 37.71374, -122.44280 37.7...
# 9975  POLYGON ((-122.44368 37.71379, -122.44374 37.7...
# 9976  POLYGON ((-122.44230 37.71451, -122.44238 37.7...
# 9977  POLYGON ((-122.48933 37.76077, -122.48971 37.7...
#
# [9978 rows x 4 columns]

# %%
# Renaming the columns. 
df2.columns = ['ZoningDistrict',
               'ZoningCode',
               'Area',
               'geometry']

# %%
#Checking to make sure the column names were updated correctly.
df2.head()
# Out:
#                             ZoningDistrict ZoningCode           Area  \
# 0  NEIGHBORHOOD COMMERCIAL, MODERATE SCALE       NC-3  13901.1426915
# 1  NEIGHBORHOOD COMMERCIAL, MODERATE SCALE       NC-3  11413.2653614
# 2  NEIGHBORHOOD COMMERCIAL, MODERATE SCALE       NC-3  14482.4919657
# 3  NEIGHBORHOOD COMMERCIAL, MODERATE SCALE       NC-3  54869.3000022
# 4  NEIGHBORHOOD COMMERCIAL, MODERATE SCALE       NC-3  12643.7618017
#
#                                             geometry
# 0  POLYGON ((-122.39202 37.73010, -122.39207 37.7...
# 1  POLYGON ((-122.39165 37.73087, -122.39172 37.7...
# 2  POLYGON ((-122.39134 37.73169, -122.39144 37.7...
# 3  POLYGON ((-122.39187 37.73195, -122.39190 37.7...
# 4  POLYGON ((-122.39103 37.73262, -122.39113 37.7...

# %%
# I want to see the number of different types of zoning districts there are in San Francisco 
df2['ZoningDistrict'].value_counts()
# Out:
# RESIDENTIAL- HOUSE, ONE FAMILY                 1949
# RESIDENTIAL- HOUSE, TWO FAMILY                 1514
# PUBLIC                                          814
# RESIDENTIAL- MIXED, LOW DENSITY                 750
# RESIDENTIAL- HOUSE, THREE FAMILY                661
#                                                ...
# RESIDENTIAL - MIXED, LOW DENSITY                  1
# PARKMERCED-COMMUNITY/FITNESS                      1
# HEAVY COMMERCIAL                                  1
# UPPER MARKET STREET NEIGHBORHOOD COMMERCIAL       1
# PARKMERCED-SCHOOL                                 1
# Name: ZoningDistrict, Length: 96, dtype: int64

# %% [markdown]
# # Focusing in on Specific Land Uses:
#
# For our project, we are most interested in looking at the land uses with inherent risk to public health such as Industry, Production, Distribution, and Repair, and the Hunter's Point Redevelopment District.

# %%
# I'm running a query to see how many Light Industrial Zones (M-1) exist in San Francisco.

df2[df2['ZoningCode']=='M-1'] #M-1 Light Industrial
# Out:
#         ZoningDistrict ZoningCode           Area  \
# 384   LIGHT INDUSTRIAL        M-1  6536.41645764
# 385   LIGHT INDUSTRIAL        M-1  19425.4747173
# 386   LIGHT INDUSTRIAL        M-1  46621.7452607
# 387   LIGHT INDUSTRIAL        M-1  34577.3287338
# 443   LIGHT INDUSTRIAL        M-1  533.756396874
# ...                ...        ...            ...
# 8578  LIGHT INDUSTRIAL        M-1  7492.45535673
# 8579  LIGHT INDUSTRIAL        M-1  111907.966555
# 8580  LIGHT INDUSTRIAL        M-1  90951.5975165
# 8581  LIGHT INDUSTRIAL        M-1   70963.257074
# 9886  LIGHT INDUSTRIAL        M-1  30868.8236865
#
#                                                geometry
# 384   POLYGON ((-122.39276 37.75221, -122.39306 37.7...
# 385   POLYGON ((-122.39620 37.78332, -122.39580 37.7...
# 386   POLYGON ((-122.38984 37.78622, -122.39060 37.7...
# 387   POLYGON ((-122.38833 37.78886, -122.38813 37.7...
# 443   POLYGON ((-122.39426 37.74373, -122.39432 37.7...
# ...                                                 ...
# 8578  POLYGON ((-122.38844 37.74001, -122.38885 37.7...
# 8579  POLYGON ((-122.38928 37.73937, -122.38942 37.7...
# 8580  POLYGON ((-122.38912 37.73980, -122.38915 37.7...
# 8581  POLYGON ((-122.38882 37.74066, -122.38887 37.7...
# 9886  POLYGON ((-122.40136 37.78202, -122.40162 37.7...
#
# [70 rows x 4 columns]

# %%
#Saving this subset as a new dataframe (m1)
m1 = df2[df2.ZoningCode =='M-1']

# %%
#Plotting the M-1 Light Industrial Zones
m1.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %%
# I'm now running the same query but for Heavy Industrial Zones (M-2)
df2[df2['ZoningCode']=='M-2'] #M-2 Heavy Industrial
# Out:
#         ZoningDistrict ZoningCode               Area  \
# 409   HEAVY INDUSTRIAL        M-2      248055.578145
# 449   HEAVY INDUSTRIAL        M-2      10915.7027815
# 461   HEAVY INDUSTRIAL        M-2      2217.87888584
# 462   HEAVY INDUSTRIAL        M-2      2091.31149466
# 463   HEAVY INDUSTRIAL        M-2      289051.281626
# 464   HEAVY INDUSTRIAL        M-2      3823.80677901
# 529   HEAVY INDUSTRIAL        M-2      87138.8056897
# 1744  HEAVY INDUSTRIAL        M-2      212.141631591
# 1827  HEAVY INDUSTRIAL        M-2      189.704985145
# 5300  HEAVY INDUSTRIAL        M-2      80667.1087102
# 5401  HEAVY INDUSTRIAL        M-2      80667.0409409
# 5591  HEAVY INDUSTRIAL        M-2      7845.45869073
# 6188  HEAVY INDUSTRIAL        M-2      1449.01066282
# 6190  HEAVY INDUSTRIAL        M-2      136059.828952
# 7524  HEAVY INDUSTRIAL        M-2      299942.542924
# 7526  HEAVY INDUSTRIAL        M-2      115652.564196
# 7530  HEAVY INDUSTRIAL        M-2      9.08766250172
# 8030  POLYGON ((-122.39152 37.74711, -122.39152 37.7...
# 8142  POLYGON ((-122.38341 37.74376, -122.38341 37.7...
# 8232  POLYGON ((-122.38099 37.76480, -122.38103 37.7...
# 8234  POLYGON ((-122.38744 37.77671, -122.38743 37.7...
# 8299  POLYGON ((-122.38440 37.78570, -122.38722 37.7...
# 8536  POLYGON ((-122.38814 37.78723, -122.38814 37.7...

# %%
#Saving the M-2 Heavy Industrial Zones as a new dataframe (df2_M2)
m2=df2[df2['ZoningCode']=='M-2']

# %%
#Plotting the M-2 zones
m2.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %%
#I'm joining the dataframes I created for the Light and Heavy Industrial zones to create one map of all industrial zone.
industrial = df2[(df2['ZoningCode'] == 'M-2') | (df2['ZoningCode']=='M-1')]

# %%
industrial.head()
# Out:
#        ZoningDistrict ZoningCode           Area  \
# 384  LIGHT INDUSTRIAL        M-1  6536.41645764
# 385  LIGHT INDUSTRIAL        M-1  19425.4747173
# 386  LIGHT INDUSTRIAL        M-1  46621.7452607
# 387  LIGHT INDUSTRIAL        M-1  34577.3287338
# 409  HEAVY INDUSTRIAL        M-2  248055.578145
#
#                                               geometry
# 384  POLYGON ((-122.39276 37.75221, -122.39306 37.7...
# 385  POLYGON ((-122.39620 37.78332, -122.39580 37.7...
# 386  POLYGON ((-122.38984 37.78622, -122.39060 37.7...
# 387  POLYGON ((-122.38833 37.78886, -122.38813 37.7...
# 409  POLYGON ((-122.37484 37.72599, -122.37498 37.7...

# %%
#Plotting the industrial zones
industrial.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Hunter's Point Data:
# Hunter's Point, a known superfund site in San Francisco, is an area of focus for our project for the inherent risk it poses to environmental public health in the city. It has it's own zoning district designated (HP-RA).

# %%
#Creating a new dataframe for the Hunter's Point district (HP-RA).
hp=df2[df2['ZoningCode']=='HP-RA']

# %%
hp.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %%
#Creating a new dataframe to combine the industrial zones with Hunter's Point
focus = df2[(df2['ZoningCode'] == 'M-2') | (df2['ZoningCode']=='M-1') | (df2['ZoningCode']=='HP-RA')]

# %%
focus.head()
# Out:
#        ZoningDistrict ZoningCode           Area  \
# 384  LIGHT INDUSTRIAL        M-1  6536.41645764
# 385  LIGHT INDUSTRIAL        M-1  19425.4747173
# 386  LIGHT INDUSTRIAL        M-1  46621.7452607
# 387  LIGHT INDUSTRIAL        M-1  34577.3287338
# 409  HEAVY INDUSTRIAL        M-2  248055.578145
#
#                                               geometry
# 384  POLYGON ((-122.39276 37.75221, -122.39306 37.7...
# 385  POLYGON ((-122.39620 37.78332, -122.39580 37.7...
# 386  POLYGON ((-122.38984 37.78622, -122.39060 37.7...
# 387  POLYGON ((-122.38833 37.78886, -122.38813 37.7...
# 409  POLYGON ((-122.37484 37.72599, -122.37498 37.7...

# %%
focus.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# Folium
#
# I'm going to import folium as the base map and then map these zones as an overlay.

# %%
import folium

# %%
m = folium.Map(location=[37.7,-122.4], 
               zoom_start = 11,
               tiles='CartoDB positron', 
               attribution='CartoDB')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e6fef0243849b6bee6a493bdfd19d3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e6fef0243849b6bee6a493bdfd19d3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e6fef0243849b6bee6a493bdfd19d3b = L.map(
#                 &quot;map_7e6fef0243849b6bee6a493bdfd19d3b&quot;,
#                 {
#                     center: [37.7, -122.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     attribution: &quot;CartoDB&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4121ad888d2748666aaecef92b3e10d7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e6fef0243849b6bee6a493bdfd19d3b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# plot choropleth over the base map
folium.Choropleth(
                  geo_data=focus, # geo data
                  data=focus, # data          
                  columns=['ZoningCode'], # [key, value]
                  fill_color='BuPu',
                  line_weight=0.1, 
                  fill_opacity=0.8,
                  line_opacity=0.5, # line opacity (of the border)
                  legend_name='Indsurial Zones in San Francisco').add_to(m)    # name on the legend
m
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[87], line 2
#       1 # plot choropleth over the base map
# ----> 2 folium.Choropleth(
#       3                   geo_data=focus, # geo data
#       4                   data=focus, # data
#       5                   columns=['ZoningCode'], # [key, value]
#       6                   fill_color='BuPu',
#       7                   line_weight=0.1,
#       8                   fill_opacity=0.8,
#       9                   line_opacity=0.5, # line opacity (of the border)
#      10                   legend_name='Indsurial Zones in San Francisco').add_to(m)    # name on the legend
#      11 m
#
# File /opt/conda/lib/python3.10/site-packages/folium/features.py:1474, in Choropleth.__init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1471 # Create color_data dict
#    1472 if hasattr(data, "set_index"):
#    1473     # This is a pd.DataFrame
# -> 1474     color_data = data.set_index(columns[0])[columns[1]].to_dict()
#    1475 elif hasattr(data, "to_dict"):
#    1476     # This is a pd.Series
#    1477     color_data = data.to_dict()
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
import contextily as ctx
import numpy as np

# %%
focus.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#starting the plot
fig, ax = plt.subplots(figsize=(20,10))

#adding the data options
focus.plot(ax=ax,
           marker='ZoningCode',
           markersize=5,
           color='purple')

#turning off the axes
ax.axis('off')

#giving it a title
ax.set_title('Industrial Land Uses and Hunters Point District 2015')

#adding a basemap
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs=4326)

# %%
focus.plot(facecolor="none")

#adding basemap
ctx.add_basemap(ax, crs=4326)

# %%
# Color coding the different zones
focus['color'] = ''

# %%
focus.head()
# Out:
#        ZoningDistrict ZoningCode           Area  \
# 384  LIGHT INDUSTRIAL        M-1  6536.41645764
# 385  LIGHT INDUSTRIAL        M-1  19425.4747173
# 386  LIGHT INDUSTRIAL        M-1  46621.7452607
# 387  LIGHT INDUSTRIAL        M-1  34577.3287338
# 409  HEAVY INDUSTRIAL        M-2  248055.578145
#
#                                               geometry color
# 384  POLYGON ((-122.39276 37.75221, -122.39306 37.7...
# 385  POLYGON ((-122.39620 37.78332, -122.39580 37.7...
# 386  POLYGON ((-122.38984 37.78622, -122.39060 37.7...
# 387  POLYGON ((-122.38833 37.78886, -122.38813 37.7...
# 409  POLYGON ((-122.37484 37.72599, -122.37498 37.7...

# %%
# setting the color for industrial zones (M-1 and M-2) to be purple
focus.loc[focus['ZoningCode'] == 'M-1', 'color'] = 'purple'
focus.loc[focus['ZoningCode'] == 'M-2', 'color'] = 'purple'

# %%
focus.head()
# Out:
#        ZoningDistrict ZoningCode           Area  \
# 384  LIGHT INDUSTRIAL        M-1  6536.41645764
# 385  LIGHT INDUSTRIAL        M-1  19425.4747173
# 386  LIGHT INDUSTRIAL        M-1  46621.7452607
# 387  LIGHT INDUSTRIAL        M-1  34577.3287338
# 409  HEAVY INDUSTRIAL        M-2  248055.578145
#
#                                               geometry   color
# 384  POLYGON ((-122.39276 37.75221, -122.39306 37.7...  purple
# 385  POLYGON ((-122.39620 37.78332, -122.39580 37.7...  purple
# 386  POLYGON ((-122.38984 37.78622, -122.39060 37.7...  purple
# 387  POLYGON ((-122.38833 37.78886, -122.38813 37.7...  purple
# 409  POLYGON ((-122.37484 37.72599, -122.37498 37.7...  purple

# %%
# setting the color for Hunter's Point to be red
focus.loc[focus['ZoningCode'] == 'HP-RA', 'color'] = 'red'

# %%
focus.loc[focus['ZoningCode'] == 'HP-RA']
# Out:
#                             ZoningDistrict ZoningCode           Area  \
# 6505  SEE HUNTERS POINT REDEVELOPMENT PLAN      HP-RA  20924325.1837
#
#                                                geometry color
# 6505  POLYGON ((-122.37547 37.72913, -122.37398 37.7...   red

# %%
#starting the plot
fig, ax = plt.subplots(figsize=(20,10))

#adding the data options
focus.plot(ax=ax,
           marker='ZoningCode',
           markersize=5,
           facecolor='none',
           edgecolor='purple')
           

#turning off the axes
ax.axis('off')

#giving it a title
ax.set_title('Industrial Land Uses and Hunters Point District 2015')

#adding a basemap
ctx.add_basemap(ax, crs=4326)

# %%
# color coding the map - creating a key
keys = list(focus['ZoningCode'].unique())

# %%
color_range = list(np.linspace(0,1, len(keys), endpoint=False))

# %%
colors = [focus['color']]

# %%
color_dict = dict(zip(keys, colors))

# %%
fig, ax = plt.subplots(figsize=(20,10))

#adding the data options
focus.plot(ax=ax,
           marker='ZoningCode',
           markersize=5)

#adding basemap
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs=4326)

# %%
#preparing the grid
row_count = focus['ZoningCode'].nunique()

# %%
ax_list = []

# %%
for i in range(row_count+1):
    ax_list.append('ax' + str(i+1))

# %%
ax_string = ', '.join(ax_list)

# %%
fig, (ax_string) = plt.subplots(row_count, 4)

# %%
ax1 = plt.subplot2grid((row_count,4),(0,1), rowspan=row_count, colspan=3)
for index, row in focus.iterrows():
    plot = focus[focus['ZoningCode'] == row['ZoningCode']].plot(color=color_dict[row['ZoningCode']], ax=ax1)
ax1.axis('off')

#adding basemap
ctx.add_basemap(ax1, source=ctx.providers.CartoDB.Positron, crs=4326)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 3
#       1 ax1 = plt.subplot2grid((row_count,4),(0,1), rowspan=row_count, colspan=3)
#       2 for index, row in focus.iterrows():
# ----> 3     plot = focus[focus['ZoningCode'] == row['ZoningCode']].plot(color=color_dict[row['ZoningCode']], ax=ax1)
#       4 ax1.axis('off')
#       6 #adding basemap
#
# KeyError: 'M-2'
